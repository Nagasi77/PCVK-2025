# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagasi77/PCVK-2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]

for url in urls :
  img = io.imread(url)
  img = cv2.resize(img, (0,0), fx = 0.5, fy = 0.5)
  img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  final_frame = cv2.hconcat([img, img_rgb])
  cv2_imshow(final_frame)
  print('\n')

last_img_rgb = img_rgb # Store the last processed image in RGB format
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = img_2.shape[0]
lebar = img_2.shape[1]
print("Resolusi img : tinggi x lebar = ",tinggi, " x ", lebar)
cv2_imshow(img_2)
# Out:
# Resolusi img : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
img_2 = cv.cvtColor(img_2, cv.COLOR_BGR2RGB)
img_3 = cv.cvtColor(img_3, cv.COLOR_BGR2RGB)

for x in range (lebar):
  img_3[int((lebar)/2),y] = [255,255,255]

final_frame = cv.hconcat((img_2, img_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
img_rgb = last_img_rgb.copy()
img_3 = img_rgb.copy()
img_4 = img_rgb.copy()
img_5 = img_rgb.copy()

tinggi = img_rgb.shape[0]
lebar = img_rgb.shape[1]



for x in range (tinggi):
  img_3[x,int((lebar)/2)] = [255,255,255]

center_x = lebar // 2
center_y = tinggi // 2
line_length = min(tinggi, lebar)

for i in range(line_length):
    img_5[center_y - line_length // 2 + i, center_x - line_length // 2 + i] = [255, 255, 255]
    img_5[center_y - line_length // 2 + i, center_x + line_length // 2 - i] = [255, 255, 255]


final_frame = cv2.hconcat((img_rgb, img_3, img_4, img_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x286>

# %%
img_2 = img_rgb.copy()
img_3 = img_rgb.copy()

tinggi = img_rgb.shape[0]
lebar = img_rgb.shape[1]

for x in range (lebar):
  img_3[int((lebar)/2),y] = [255,255,255]

  final_frame = cv.hconcat((img_2, img_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
